# %% [markdown]
# # Stem Cell Simulation
# ### Description
# Stem cell simulation made by Achmad Zacky Fairuza
#
# ### Import Modules

# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np
import stemcell as sc
# Out:
# C:\mydata\code\Stem_Cell2\stemcell.py:562: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if target.object_type is 'ligand':
# C:\mydata\code\Stem_Cell2\stemcell.py:574: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif target.object_type is 'integrin':

# %% [markdown]
# ### Reloading Stemcell Module
#
# Use this script to reload module if there is an update on stemcell module

# %%
importlib.reload(sc)
# Out:
# <module 'stemcell' from 'C:\\mydata\\code\\Stem_Cell2\\stemcell.py'>

# %% [markdown]
# ### Read PATCON File
# PATCON.txt File contains the configuration settings for the nanopattern

# %%
# open file
patcon = sc.readFile('PATCON')

# get value
dot_number = sc.getValue(patcon, 'dotnumber')
grid_size = sc.getValue(patcon, 'unitsize')
substrate_size = sc.getValue(patcon, 'subsize')
dot_size = sc.getValue(patcon, 'dotsize')
ligand_position = sc.getValue(patcon,'LIGAND')

# %% [markdown]
# ### Build Nanopattern
# Build nanopattern from the patcon file

# %%
sc.Ligand.resetNumber()
substrate = sc.Nanopattern(substrate_size[0], substrate_size[1], grid_size[0], grid_size[1], ligand_position, dot_size)
substrate.show(True, folder='nanopatern')
# Out:
# nanopattern has been created
# figure saved on ./figure/nanopatern

# %%
print(sc.Ligand.ligand_number)
# Out:
# 800

# %% [markdown]
# ### Read CELCON File
# CELCON.txt contain the configuration for the cells.

# %%
# open file
celcon = sc.readFile('CELCON')

# get value
cell_number = sc.getValue(celcon, 'cellnumber')
integrin_size = sc.getValue(celcon, 'ressize')
integrin_mass = sc.getValue(celcon, 'resmass')
cell_properties = sc.getValue(celcon, 'CELL')

# %%
print(cell_properties)
# Out:
# [[2500.0, 2500.0, 250.0, 70.0, 100.0]]

# %% [markdown]
# ### Build Cells
# Build cells from the CELCON file

# %%
# reset the cell and integrin counter 
sc.Integrin.resetNumber()
sc.Cell.resetNumber()

# build the cell
cells = []
for obj in cell_properties:
    build_cell = sc.Cell(obj[0], obj[1], obj[2], obj[3], obj[4], integrin_size)
    cells.append(build_cell)
    build_cell.show(substrate)


#print cell and integrin counter
print(sc.Cell.cell_number)
print(sc.Integrin.integrin_number)
# Out:
# 1
# 70

# %%
sc.showAll(cells, substrate, show_substrate=True, save=True, folder='all')
# Out:
# figure 000000.jpg saved on ./figure/all

# %%
importlib.reload(sc)
sc.simulate1(cells, substrate, movespeed=5, dstlimit=750, n_iteration=50)
# Out:
# figure 000000.jpg saved on ./figure/simulation_output
# figure 000001.jpg saved on ./figure/simulation_output
# figure 000002.jpg saved on ./figure/simulation_output
# figure 000003.jpg saved on ./figure/simulation_output
# figure 000004.jpg saved on ./figure/simulation_output
# figure 000005.jpg saved on ./figure/simulation_output
# figure 000006.jpg saved on ./figure/simulation_output
# figure 000007.jpg saved on ./figure/simulation_output
# figure 000008.jpg saved on ./figure/simulation_output
# figure 000009.jpg saved on ./figure/simulation_output
# figure 000010.jpg saved on ./figure/simulation_output
# figure 000011.jpg saved on ./figure/simulation_output
# figure 000012.jpg saved on ./figure/simulation_output
# figure 000013.jpg saved on ./figure/simulation_output
# figure 000014.jpg saved on ./figure/simulation_output
# figure 000015.jpg saved on ./figure/simulation_output
# figure 000016.jpg saved on ./figure/simulation_output
# figure 000017.jpg saved on ./figure/simulation_output
# figure 000018.jpg saved on ./figure/simulation_output
# figure 000019.jpg saved on ./figure/simulation_output
# figure 000020.jpg saved on ./figure/simulation_output
# figure 000021.jpg saved on ./figure/simulation_output
# figure 000022.jpg saved on ./figure/simulation_output
# figure 000023.jpg saved on ./figure/simulation_output
# figure 000024.jpg saved on ./figure/simulation_output
# figure 000025.jpg saved on ./figure/simulation_output
# figure 000026.jpg saved on ./figure/simulation_output
# figure 000027.jpg saved on ./figure/simulation_output
# figure 000028.jpg saved on ./figure/simulation_output
# figure 000029.jpg saved on ./figure/simulation_output
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-c47b65b3a5ff> in <module>
#       1 importlib.reload(sc)
# ----> 2 sc.simulate1(cells, substrate, movespeed=5, dstlimit=750, n_iteration=50)
#
# C:\mydata\code\Stem_Cell2\stemcell.py in simulate1(cells, substrate, dstlimit, n_iteration, movespeed)
#     618                         #print('integrin moving')
#     619                         integrin.move(movespeed)
# --> 620         showAll(cells, substrate, show_substrate=True, save=True,
#     621             folder='simulation_output', number=iter_simulation)
#     622         iter_simulation += 1
#
# C:\mydata\code\Stem_Cell2\stemcell.py in showAll(cells, substrate, show_substrate, save, number, folder)
#     482     if save is True:
#     483         print(f'figure {number:06}.jpg saved on {namefolder}')
# --> 484         fig.savefig(namefile, bbox_inches='tight', dpi=600)
#     485         plt.close()
#     486
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2960                 patch.set_edgecolor('none')
#    2961
# -> 2962         self.canvas.print_figure(fname, **kwargs)
#    2963
#    2964         if transparent:
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backends\backend_agg.py in print_jpg(self, filename_or_obj, pil_kwargs, *args, **kwargs)
#     582         pil_kwargs.setdefault("dpi", (self.figure.dpi, self.figure.dpi))
#     583         # Drop alpha channel now.
# --> 584         return (Image.fromarray(np.asarray(self.buffer_rgba())[..., :3])
#     585                 .save(filename_or_obj, format='jpeg', **pil_kwargs))
#     586
#
# ~\AppData\Roaming\Python\Python39\site-packages\PIL\Image.py in fromarray(obj, mode)
#    2791             obj = obj.tostring()
#    2792
# -> 2793     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2794
#    2795
#
# ~\AppData\Roaming\Python\Python39\site-packages\PIL\Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2731             return im
#    2732
# -> 2733     return frombytes(mode, size, data, decoder_name, args)
#    2734
#    2735
#
# ~\AppData\Roaming\Python\Python39\site-packages\PIL\Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2676         args = mode
#    2677
# -> 2678     im = new(mode, size)
#    2679     im.frombytes(data, decoder_name, args)
#    2680     return im
#
# ~\AppData\Roaming\Python\Python39\site-packages\PIL\Image.py in new(mode, size, color)
#    2640         im.palette = ImagePalette.ImagePalette()
#    2641         color = im.palette.getcolor(color)
# -> 2642     return im._new(core.fill(mode, size, color))
#    2643
#    2644
#
# MemoryError:

# %%
for integrin in cells[0].integrin:
    print(integrin.getInformation())

# %%
a = sc.Ligand(1,1)
b = type(a)
if type(a) == sc.Ligand:
    print(b)
    print(a.__dict__)

# %%
np.arctan2(1,2)
